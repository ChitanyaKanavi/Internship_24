# %%
import selenium 
from selenium import webdriver
import pandas as pd
import warnings
import requests
warnings.filterwarnings("ignore")
import time

driver = webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver_win32 (1)\chromedriver.exe')
# driver = webdriver.Chrome('chromedriver.exe')
url= "https://www.flipkart.com/"
driver.get(url)
button = driver.find_element_by_xpath('/html/body/div[2]/div/div/button').click()
search=driver.find_element_by_class_name("_3704LK")
search.send_keys("sneakers")
search1=driver.find_element_by_class_name("L0Z3Pu").click()      # search
time.sleep(5)

# %%
href_urls = [my_elem.get_attribute("href") for my_elem in driver.find_elements_by_css_selector("nav.yFHi8N > a")] 
brand=[]
des=[]
prices=[]
offers=[]

for i in range(0,3):
    page = requests.get(url)   #url page
    driver = webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver_win32 (1)\chromedriver.exe')
    url= href_urls[i]
    driver.get(url)
    time.sleep(2) 
    brand_name = driver.find_elements_by_xpath('//div[@class="_2WkVRV"]')
    for l in brand_name:
        brand.append(l.text)
        describe = driver.find_elements_by_xpath('//a[contains(@class, "IRpwTa") or contains(@class,"IRpwTa _2-ICcC")]')
    for j in describe:
        des.append(j.text)
        price = driver.find_elements_by_xpath('//div[@class="_30jeq3"]')
    for k in price:
        prices.append(k.text)
        offer = driver.find_elements_by_xpath('//div[@class="_3Ay6Sb"]')
    for m in offer:
        if m.text == ' ':
            offers.append("No offer found")
        else:
                offers.append(m.text)


df = pd.DataFrame()
df['Brand']= brand
df['Price']= prices
df['Offer']= offers
df['Describe']=des
df.head(100)
# Out:
#            Brand   Price    Offer  \
# 0          BOOYO    ₹405  77% off
# 1       RapidBox    ₹580  41% off
# 2         BRUTON    ₹209  83% off
# 3       Elevarse    ₹299  70% off
# 4         BRUTON    ₹449  87% off
# ..           ...     ...      ...
# 95      Roadster  ₹1,649  50% off
# 96         SPARX    ₹714  15% off
# 97         BIRDE    ₹209  79% off
# 98          Eliq    ₹233  53% off
# 99  Mr ShoesWala    ₹382  61% off
#
#                                              Describe
# 0                   Sneakers For Men Sneakers For Men
# 1                   Stylish & Trendy Sneakers For Men
# 2       Modern Trendy Sneakers Shoes Sneakers For Men
# 3                                    Sneakers For Men
# 4   Combo Pack Of 4 Casual Shoes Loafer Shoes Snea...
# ..                                                ...
# 95           Men Blue Solid Sneakers Sneakers For Men
# 96                            SM-175 Sneakers For Men
# 97  Comfortable Stylish New Design Light Weight, B...
# 98  Men's & Boy's Sneaker Blue Shoes Casual Sneake...
# 99  Men's Casual Shoes in White Color Walking Runn...
#
# [100 rows x 4 columns]

# %%
print(len(offers))
print(len(prices))
print(len(brand))
print(len(des))
# Out:
# 120
# 120
# 120
# 120
